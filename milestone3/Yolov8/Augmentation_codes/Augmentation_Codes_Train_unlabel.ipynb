# %% [markdown]
# Cropped

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Define original image directory
image_dir = r'C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original.jpg'

# Define separate output directory for cropped images
save_dir = r'C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original_cropped.jpg'
os.makedirs(save_dir, exist_ok=True)

# Get up to 1000 .jpg files from the source folder
image_filenames = [
    fname for fname in os.listdir(image_dir)
    if fname.lower().endswith(".jpg")
][:1000]

# Crop and save images
for fname in image_filenames:
    image_path = os.path.join(image_dir, fname)
    img = cv2.imread(image_path)

    if img is None:
        print(f"Error: Failed to load {fname}")
        continue

    height, width = img.shape[:2]

    # Define cropping coordinates for center crop (smallest square)
    min_dim = min(height, width)
    start_x = (width - min_dim) // 2
    start_y = (height - min_dim) // 2
    end_x = start_x + min_dim
    end_y = start_y + min_dim

    cropped_img = img[start_y:end_y, start_x:end_x]

    save_path = os.path.join(save_dir, f"cropped_{fname}")
    cv2.imwrite(save_path, cropped_img)
    print(f"Saved: {save_path}")

print("All images cropped and saved in a separate folder!")

# --- Display the first cropped image ---

cropped_files = [f for f in os.listdir(save_dir) if f.lower().endswith(".jpg")]
if cropped_files:
    first_image_path = os.path.join(save_dir, cropped_files[0])
    test_image = cv2.imread(first_image_path)
    test_image_rgb = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    plt.imshow(test_image_rgb)
    plt.axis("off")
    plt.title(f"Sample: {cropped_files[0]}")
    plt.show()
else:
    print("No cropped images found to display.")
# Out:
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original_cropped.jpg\cropped_110.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original_cropped.jpg\cropped_113.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original_cropped.jpg\cropped_114.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original_cropped.jpg\cropped_115.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original_cropped.jpg\cropped_12.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original_cropped.jpg\cropped_120.jpg
# ...

# %% [markdown]
# Flipped

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Define original image directory
image_dir = r'C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1.jpg'

# Define output directory for flipped images
save_dir = r'C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1_flip.jpg'
os.makedirs(save_dir, exist_ok=True)

# Get up to 1000 .jpg files
image_filenames = [
    fname for fname in os.listdir(image_dir)
    if fname.lower().endswith(".jpg")
][:1000]

# Flip and save images
for fname in image_filenames:
    image_path = os.path.join(image_dir, fname)
    img = cv2.imread(image_path)

    if img is None:
        print(f"Error: Failed to load {fname}")
        continue

    # Flip horizontally (flipCode=1)
    flipped_img = cv2.flip(img, 1)

    save_path = os.path.join(save_dir, f"flipped_{fname}")
    cv2.imwrite(save_path, flipped_img)
    print(f"Saved: {save_path}")

print("All images flipped and saved in a separate folder!")

# --- Display the first flipped image ---

flipped_files = [f for f in os.listdir(save_dir) if f.lower().endswith(".jpg")]
if flipped_files:
    first_image_path = os.path.join(save_dir, flipped_files[0])
    test_image = cv2.imread(first_image_path)
    test_image_rgb = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    plt.imshow(test_image_rgb)
    plt.axis("off")
    plt.title(f"Sample: {flipped_files[0]}")
    plt.show()
else:
    print("No flipped images found to display.")
# Out:
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1_flip.jpg\flipped_110.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1_flip.jpg\flipped_113.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1_flip.jpg\flipped_114.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1_flip.jpg\flipped_115.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1_flip.jpg\flipped_12.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1_flip.jpg\flipped_120.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1_flip.jpg\flipped_123.jpg
# ...

# %% [markdown]
# Resized

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Define original image directory
image_dir = r'C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1.jpg'

# Define separate output directory (NOT inside image_dir)
save_dir = r'C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_resize.jpg'
os.makedirs(save_dir, exist_ok=True)  # Create output folder if it doesn't exist

# Define new size for resizing
new_size = (250, 250)

# Get up to 1000 .jpg files from image_dir
image_filenames = [
    fname for fname in os.listdir(image_dir)
    if fname.lower().endswith(".jpg")
][:1000]

# Resize and save images
for fname in image_filenames:
    image_path = os.path.join(image_dir, fname)
    img = cv2.imread(image_path)

    if img is None:
        print(f"Error: Failed to load {fname}")
        continue

    resized_img = cv2.resize(img, new_size, interpolation=cv2.INTER_LINEAR)
    save_path = os.path.join(save_dir, f"resized_{fname}")
    cv2.imwrite(save_path, resized_img)
    print(f"Saved: {save_path}")

print("All images resized and saved in a separate folder!")

# --- Display the first successfully resized image ---

# Find the first resized image in the save directory
resized_files = [f for f in os.listdir(save_dir) if f.lower().endswith(".jpg")]
if resized_files:
    first_image_path = os.path.join(save_dir, resized_files[0])
    test_image = cv2.imread(first_image_path)
    test_image_rgb = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    plt.imshow(test_image_rgb)
    plt.axis("off")
    plt.title(f"Sample: {resized_files[0]}")
    plt.show()
else:
    print("No resized images found to display.")
# Out:
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_resize.jpg\resized_110.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_resize.jpg\resized_113.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_resize.jpg\resized_114.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_resize.jpg\resized_115.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_resize.jpg\resized_12.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_resize.jpg\resized_120.jpg
# ...

# %% [markdown]
# Rotated

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Define original image directory
image_dir = r'C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\Original1.jpg'

# Define separate output directory for rotated images
save_dir = r'C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_rotate.jpg'
os.makedirs(save_dir, exist_ok=True)

# Get up to 1000 .jpg files from the source folder
image_filenames = [
    fname for fname in os.listdir(image_dir)
    if fname.lower().endswith(".jpg")
][:1000]

# Rotate and save images
for fname in image_filenames:
    image_path = os.path.join(image_dir, fname)
    img = cv2.imread(image_path)

    if img is None:
        print(f"Error: Failed to load {fname}")
        continue

    height, width = img.shape[:2]
    center = (width // 2, height // 2)

    # Create rotation matrix for 180 degrees
    rotate_matrix = cv2.getRotationMatrix2D(center=center, angle=180, scale=1)
    rotated_img = cv2.warpAffine(img, rotate_matrix, (width, height))

    save_path = os.path.join(save_dir, f"rotated_{fname}")
    cv2.imwrite(save_path, rotated_img)
    print(f"Saved: {save_path}")

print("All images rotated and saved in a separate folder!")

# --- Display the first rotated image ---

rotated_files = [f for f in os.listdir(save_dir) if f.lower().endswith(".jpg")]
if rotated_files:
    first_image_path = os.path.join(save_dir, rotated_files[0])
    test_image = cv2.imread(first_image_path)
    test_image_rgb = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    plt.imshow(test_image_rgb)
    plt.axis("off")
    plt.title(f"Sample: {rotated_files[0]}")
    plt.show()
else:
    print("No rotated images found to display.")
# Out:
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_rotate.jpg\rotated_110.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_rotate.jpg\rotated_113.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_rotate.jpg\rotated_114.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_rotate.jpg\rotated_115.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_rotate.jpg\rotated_12.jpg
# Saved: C:\Users\Reshmi\Capstone-Project\milestone3\Yolov8\Train_Val_Test_with_augumentation\Images\Train\original1_rotate.jpg\rotated_120.jpg
# ...
