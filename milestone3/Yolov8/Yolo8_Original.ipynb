# %%
#pip install ultralytics
# Out:
# ...
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ------------------------------- -------- 0.8/1.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 1.2 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/11.5 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/11.5 MB 1.3 MB/s eta 0:00:08
# ...

# %%
from ultralytics import YOLO

# Path to the model config
# Choose one: 'yolov8n.pt', 'yolov8s.pt', 'yolov9c.pt', etc.
model_name = 'yolov8n.pt'  # lightweight, fast — change to yolov9/10 if needed

# Path to your data.yaml file
data_yaml_path = 'C:/Users/Reshmi/Capstone-Project/milestone3/Yolov8/data.yaml'

# Create YOLO model (loads pretrained weights)
model = YOLO(model_name)

# Train the model
model.train(
    data=data_yaml_path,
    epochs=160,
    imgsz=240,
    batch=16,            # adjust based on your GPU
    name='dental_caries_model',
    project='C:/Users/Reshmi/Capstone-Project/milestone3/models',  # path to save models
    exist_ok=True,       # overwrite existing project                           
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.128 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.127  Python-3.12.9 torch-2.7.0+cpu CPU (AMD Ryzen 5 5500U with Radeon Graphics)
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# Load trained model
model = YOLO('/Users/sandeepreddy/Desktop/greencard/GreenCard/models/dental_caries_model/weights/best.pt')

image_path = '/Users/sandeepreddy/Desktop/greencard/GreenCard/predict_test/67_jpg.rf.0faeace3f8c6fe5496f1bf1bbd47cf94.jpg'

# Run prediction and save output
results = model(image_path, save=True)

predicted_image_path = os.path.join('runs', 'detect', 'predict', os.path.basename(image_path))

# Load and display with matplotlib
img = mpimg.imread(predicted_image_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.title("YOLO Prediction with Bounding Boxes")
plt.axis('off')
plt.show()
# Out:
# Ultralytics YOLOv8.0.9 🚀 Python-3.9.6 torch-2.0.1 CPU
# Fusing layers...
# Model summary: 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
# Results saved to runs/detect/predict
